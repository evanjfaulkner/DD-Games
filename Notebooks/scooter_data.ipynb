# %%
import math
import time
import requests
import numpy as np
import pandas as pd

lime = "https://data.lime.bike/api/partners/v1/gbfs/seattle/free_bike_status.json"
link = "https://wrangler-mds-production.herokuapp.com/gbfs/Seattle,%20WA/free_bike_status.json"
wheels = "https://seattle-gbfs.getwheelsapp.com/free_bike_status.json"

# %%
def get_status():
    print('getting status...')
    lime_json = requests.get(lime).text
    link_json = requests.get(link).text
    wheels_json = requests.get(wheels).text
    
    timestamp_lime = pd.read_json(lime_json)['last_updated'][0]
    data_lime = pd.DataFrame(pd.read_json(lime_json)['data'][0])
    data_lime.insert(1,'timestamp',timestamp_lime)
    data_lime.insert(0,'company','lime')
    timestamp_link = pd.read_json(link_json)['last_updated'][0]
    data_link = pd.DataFrame(pd.read_json(link_json)['data'][0])
    data_link.insert(1,'timestamp',timestamp_link)
    data_link.insert(0,'company','link')
    timestamp_wheels = pd.read_json(wheels_json)['last_updated'][0]
    data_wheels = pd.DataFrame(pd.read_json(wheels_json)['data'][0])
    data_wheels.insert(1,'timestamp',timestamp_wheels)
    data_wheels.insert(0,'company','wheels')

    frames = [data_lime, data_link, data_wheels]
    times = [timestamp_lime, timestamp_link, timestamp_wheels]
    return frames, times

# %%
frames_new, times_new = get_status()
data_new = pd.concat(frames_new, ignore_index=True)
data = data_new

for i in range(480):
    times_old = times_new
    frames_new, times_new = get_status()
#     print(times_new)
    if times_new[0] != times_old[0]:
        print('adding new lime data')
        data = pd.concat([data, frames_new[0]], ignore_index=True)
    if times_new[1] != times_old[1]:
        print('adding new link data')
        data = pd.concat([data, frames_new[1]], ignore_index=True)
    if times_new[2] != times_old[2]:
        print('adding new wheels data')
        data = pd.concat([data, frames_new[2]], ignore_index=True)
    print(f'{data.shape[0]} rows')
    time.sleep(30)
# Out:
# getting status...
# getting status...
# adding new link data
# adding new wheels data
# 6852 rows
# getting status...
# adding new link data
# adding new wheels data
# 9650 rows
# getting status...
# adding new link data
# adding new wheels data
# 12450 rows
# getting status...
# adding new link data
# adding new wheels data
# 15254 rows
# getting status...
# adding new link data
# adding new wheels data
# 18060 rows
# getting status...
# adding new link data
# adding new wheels data
# 20866 rows
# getting status...
# adding new link data
# adding new wheels data
# 23678 rows
# getting status...
# adding new link data
# adding new wheels data
# 26486 rows
# getting status...
# adding new link data
# adding new wheels data
# 29294 rows
# getting status...
# adding new link data
# adding new wheels data
# 32102 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 36146 rows
# getting status...
# adding new link data
# adding new wheels data
# 38952 rows
# getting status...
# adding new link data
# adding new wheels data
# 41759 rows
# getting status...
# adding new link data
# adding new wheels data
# 44565 rows
# getting status...
# adding new link data
# adding new wheels data
# 47371 rows
# getting status...
# adding new link data
# adding new wheels data
# 50178 rows
# getting status...
# adding new link data
# adding new wheels data
# 52985 rows
# getting status...
# adding new link data
# adding new wheels data
# 55791 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 59833 rows
# getting status...
# adding new link data
# adding new wheels data
# 62642 rows
# getting status...
# adding new link data
# adding new wheels data
# 65451 rows
# getting status...
# adding new link data
# adding new wheels data
# 68261 rows
# getting status...
# adding new link data
# adding new wheels data
# 71071 rows
# getting status...
# adding new link data
# adding new wheels data
# 73882 rows
# getting status...
# adding new link data
# adding new wheels data
# 76693 rows
# getting status...
# adding new link data
# adding new wheels data
# 79504 rows
# getting status...
# adding new link data
# adding new wheels data
# 82331 rows
# getting status...
# adding new link data
# adding new wheels data
# 85158 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 89217 rows
# getting status...
# adding new link data
# adding new wheels data
# 92055 rows
# getting status...
# adding new link data
# adding new wheels data
# 94892 rows
# getting status...
# adding new link data
# adding new wheels data
# 97729 rows
# getting status...
# adding new link data
# adding new wheels data
# 100565 rows
# getting status...
# adding new link data
# adding new wheels data
# 103401 rows
# getting status...
# adding new link data
# adding new wheels data
# 106236 rows
# getting status...
# adding new link data
# adding new wheels data
# 109073 rows
# getting status...
# adding new link data
# adding new wheels data
# 111911 rows
# getting status...
# adding new link data
# adding new wheels data
# 114750 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 118822 rows
# getting status...
# adding new link data
# adding new wheels data
# 121664 rows
# getting status...
# adding new link data
# adding new wheels data
# 124507 rows
# getting status...
# adding new link data
# adding new wheels data
# 127349 rows
# getting status...
# adding new link data
# adding new wheels data
# 130192 rows
# getting status...
# adding new link data
# adding new wheels data
# 133035 rows
# getting status...
# adding new link data
# adding new wheels data
# 135878 rows
# getting status...
# adding new link data
# adding new wheels data
# 138721 rows
# getting status...
# adding new link data
# adding new wheels data
# 141564 rows
# getting status...
# adding new link data
# adding new wheels data
# 144407 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 148476 rows
# getting status...
# adding new link data
# adding new wheels data
# 151319 rows
# getting status...
# adding new link data
# adding new wheels data
# 154162 rows
# getting status...
# adding new link data
# adding new wheels data
# 157004 rows
# getting status...
# adding new link data
# adding new wheels data
# 159846 rows
# getting status...
# adding new link data
# adding new wheels data
# 162684 rows
# getting status...
# adding new link data
# adding new wheels data
# 165522 rows
# getting status...
# adding new link data
# adding new wheels data
# 168361 rows
# getting status...
# adding new link data
# adding new wheels data
# 171200 rows
# getting status...
# adding new link data
# adding new wheels data
# 174039 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 178106 rows
# getting status...
# adding new link data
# adding new wheels data
# 180947 rows
# getting status...
# adding new link data
# adding new wheels data
# 183790 rows
# getting status...
# adding new link data
# adding new wheels data
# 186633 rows
# getting status...
# adding new link data
# adding new wheels data
# 189475 rows
# getting status...
# adding new link data
# adding new wheels data
# 192327 rows
# getting status...
# adding new link data
# adding new wheels data
# 195180 rows
# getting status...
# adding new link data
# adding new wheels data
# 198032 rows
# getting status...
# adding new link data
# adding new wheels data
# 200888 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 204968 rows
# getting status...
# adding new link data
# adding new wheels data
# 207824 rows
# getting status...
# adding new link data
# adding new wheels data
# 210680 rows
# getting status...
# adding new link data
# adding new wheels data
# 213536 rows
# getting status...
# adding new link data
# adding new wheels data
# 216392 rows
# getting status...
# adding new link data
# adding new wheels data
# 219248 rows
# getting status...
# adding new link data
# adding new wheels data
# 222104 rows
# getting status...
# adding new link data
# adding new wheels data
# 224961 rows
# getting status...
# adding new link data
# adding new wheels data
# 227816 rows
# getting status...
# adding new link data
# adding new wheels data
# 230672 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 234749 rows
# getting status...
# adding new link data
# adding new wheels data
# 237606 rows
# getting status...
# adding new link data
# adding new wheels data
# 240465 rows
# getting status...
# adding new link data
# adding new wheels data
# 243324 rows
# getting status...
# adding new link data
# adding new wheels data
# 246182 rows
# getting status...
# adding new link data
# adding new wheels data
# 249040 rows
# getting status...
# adding new link data
# adding new wheels data
# 251897 rows
# getting status...
# adding new link data
# adding new wheels data
# 254754 rows
# getting status...
# adding new link data
# adding new wheels data
# 257612 rows
# getting status...
# adding new link data
# adding new wheels data
# 260472 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 264562 rows
# getting status...
# adding new link data
# adding new wheels data
# 267430 rows
# getting status...
# adding new link data
# adding new wheels data
# 270300 rows
# getting status...
# adding new link data
# adding new wheels data
# 273170 rows
# getting status...
# adding new link data
# adding new wheels data
# 276040 rows
# getting status...
# adding new link data
# adding new wheels data
# 278909 rows
# getting status...
# adding new link data
# adding new wheels data
# 281775 rows
# getting status...
# adding new link data
# adding new wheels data
# 284641 rows
# getting status...
# adding new link data
# adding new wheels data
# 287504 rows
# getting status...
# adding new link data
# adding new wheels data
# 290367 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 294454 rows
# getting status...
# adding new link data
# adding new wheels data
# 297319 rows
# getting status...
# adding new link data
# adding new wheels data
# 300184 rows
# getting status...
# adding new link data
# adding new wheels data
# 303049 rows
# getting status...
# adding new link data
# adding new wheels data
# 305912 rows
# getting status...
# adding new link data
# adding new wheels data
# 308774 rows
# getting status...
# adding new link data
# adding new wheels data
# 311636 rows
# getting status...
# adding new link data
# adding new wheels data
# 314497 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 318585 rows
# getting status...
# adding new link data
# adding new wheels data
# 321440 rows
# getting status...
# adding new link data
# adding new wheels data
# 324295 rows
# getting status...
# adding new link data
# adding new wheels data
# 327150 rows
# getting status...
# adding new link data
# adding new wheels data
# 330005 rows
# getting status...
# adding new link data
# adding new wheels data
# 332861 rows
# getting status...
# adding new link data
# adding new wheels data
# 335717 rows
# getting status...
# adding new link data
# adding new wheels data
# 338572 rows
# getting status...
# adding new link data
# adding new wheels data
# 341429 rows
# getting status...
# adding new link data
# adding new wheels data
# 344285 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 348379 rows
# getting status...
# adding new link data
# adding new wheels data
# 351236 rows
# getting status...
# adding new link data
# adding new wheels data
# 354094 rows
# getting status...
# adding new link data
# adding new wheels data
# 356952 rows
# getting status...
# adding new link data
# adding new wheels data
# 359808 rows
# getting status...
# adding new link data
# adding new wheels data
# 362663 rows
# getting status...
# adding new link data
# adding new wheels data
# 365519 rows
# getting status...
# adding new link data
# adding new wheels data
# 368375 rows
# getting status...
# adding new link data
# adding new wheels data
# 371232 rows
# getting status...
# adding new link data
# adding new wheels data
# 374089 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 378200 rows
# getting status...
# adding new link data
# adding new wheels data
# 381057 rows
# getting status...
# adding new link data
# adding new wheels data
# 383913 rows
# getting status...
# adding new link data
# adding new wheels data
# 386769 rows
# getting status...
# adding new link data
# adding new wheels data
# 389625 rows
# getting status...
# adding new link data
# adding new wheels data
# 392481 rows
# getting status...
# adding new link data
# adding new wheels data
# 395336 rows
# getting status...
# adding new link data
# adding new wheels data
# 398192 rows
# getting status...
# adding new link data
# adding new wheels data
# 401048 rows
# getting status...
# adding new link data
# adding new wheels data
# 403888 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 407977 rows
# getting status...
# adding new link data
# adding new wheels data
# 410816 rows
# getting status...
# adding new link data
# adding new wheels data
# 413655 rows
# getting status...
# adding new link data
# adding new wheels data
# 416494 rows
# getting status...
# adding new link data
# adding new wheels data
# 419333 rows
# getting status...
# adding new link data
# adding new wheels data
# 422171 rows
# getting status...
# adding new link data
# adding new wheels data
# 425010 rows
# getting status...
# adding new link data
# adding new wheels data
# 427851 rows
# getting status...
# adding new link data
# adding new wheels data
# 430691 rows
# getting status...
# adding new link data
# adding new wheels data
# 433531 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 437626 rows
# getting status...
# adding new link data
# adding new wheels data
# 440466 rows
# getting status...
# adding new link data
# adding new wheels data
# 443305 rows
# getting status...
# adding new link data
# adding new wheels data
# 446144 rows
# getting status...
# adding new link data
# adding new wheels data
# 448983 rows
# getting status...
# adding new link data
# adding new wheels data
# 451821 rows
# getting status...
# adding new link data
# adding new wheels data
# 454659 rows
# getting status...
# adding new link data
# adding new wheels data
# 457497 rows
# getting status...
# adding new link data
# adding new wheels data
# 460335 rows
# getting status...
# adding new link data
# adding new wheels data
# 463173 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 467268 rows
# getting status...
# adding new link data
# adding new wheels data
# 470107 rows
# getting status...
# adding new link data
# adding new wheels data
# 472946 rows
# getting status...
# adding new link data
# adding new wheels data
# 475783 rows
# getting status...
# adding new link data
# adding new wheels data
# 478620 rows
# getting status...
# adding new link data
# adding new wheels data
# 481457 rows
# getting status...
# adding new link data
# adding new wheels data
# 484291 rows
# getting status...
# adding new link data
# adding new wheels data
# 487124 rows
# getting status...
# adding new link data
# adding new wheels data
# 489958 rows
# getting status...
# adding new link data
# adding new wheels data
# 492791 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 496864 rows
# getting status...
# adding new link data
# adding new wheels data
# 499696 rows
# getting status...
# adding new link data
# adding new wheels data
# 502528 rows
# getting status...
# adding new link data
# adding new wheels data
# 505360 rows
# getting status...
# adding new link data
# adding new wheels data
# 508194 rows
# getting status...
# adding new link data
# adding new wheels data
# 511029 rows
# getting status...
# adding new link data
# adding new wheels data
# 513865 rows
# getting status...
# adding new link data
# adding new wheels data
# 516701 rows
# getting status...
# adding new link data
# adding new wheels data
# 519537 rows
# getting status...
# adding new link data
# adding new wheels data
# 522372 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 526457 rows
# getting status...
# adding new link data
# adding new wheels data
# 529292 rows
# getting status...
# adding new link data
# adding new wheels data
# 532127 rows
# getting status...
# adding new link data
# adding new wheels data
# 534963 rows
# getting status...
# adding new link data
# adding new wheels data
# 537797 rows
# getting status...
# adding new link data
# adding new wheels data
# 540633 rows
# getting status...
# adding new link data
# adding new wheels data
# 543469 rows
# getting status...
# adding new link data
# adding new wheels data
# 546305 rows
# getting status...
# adding new link data
# adding new wheels data
# 549141 rows
# getting status...
# adding new link data
# adding new wheels data
# 551976 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 556074 rows
# getting status...
# adding new link data
# adding new wheels data
# 558911 rows
# getting status...
# adding new link data
# adding new wheels data
# 561746 rows
# getting status...
# adding new link data
# adding new wheels data
# 564583 rows
# getting status...
# adding new link data
# adding new wheels data
# 567420 rows
# getting status...
# adding new link data
# adding new wheels data
# 570257 rows
# getting status...
# adding new link data
# adding new wheels data
# 573093 rows
# getting status...
# adding new link data
# adding new wheels data
# 575930 rows
# getting status...
# adding new link data
# adding new wheels data
# 578767 rows
# getting status...
# adding new link data
# adding new wheels data
# 581602 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 585683 rows
# getting status...
# adding new link data
# adding new wheels data
# 588516 rows
# getting status...
# adding new link data
# adding new wheels data
# 591349 rows
# getting status...
# adding new link data
# adding new wheels data
# 594182 rows
# getting status...
# adding new link data
# adding new wheels data
# 597015 rows
# getting status...
# adding new link data
# adding new wheels data
# 599848 rows
# getting status...
# adding new link data
# adding new wheels data
# 602681 rows
# getting status...
# adding new link data
# adding new wheels data
# 605513 rows
# getting status...
# adding new link data
# adding new wheels data
# 608343 rows
# getting status...
# adding new link data
# adding new wheels data
# 611174 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 615240 rows
# getting status...
# adding new link data
# adding new wheels data
# 618068 rows
# getting status...
# adding new link data
# adding new wheels data
# 620896 rows
# getting status...
# adding new link data
# adding new wheels data
# 623734 rows
# getting status...
# adding new link data
# adding new wheels data
# 626570 rows
# getting status...
# adding new link data
# adding new wheels data
# 629405 rows
# getting status...
# adding new link data
# adding new wheels data
# 632239 rows
# getting status...
# adding new link data
# adding new wheels data
# 635073 rows
# getting status...
# adding new link data
# adding new wheels data
# 637917 rows
# getting status...
# adding new link data
# adding new wheels data
# 640762 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 644836 rows
# getting status...
# adding new link data
# adding new wheels data
# 647679 rows
# getting status...
# adding new link data
# adding new wheels data
# 650523 rows
# getting status...
# adding new link data
# adding new wheels data
# 653365 rows
# getting status...
# adding new link data
# adding new wheels data
# 656207 rows
# getting status...
# adding new link data
# adding new wheels data
# 659049 rows
# getting status...
# adding new link data
# adding new wheels data
# 661891 rows
# getting status...
# adding new link data
# adding new wheels data
# 664733 rows
# getting status...
# adding new link data
# adding new wheels data
# 667575 rows
# getting status...
# adding new link data
# adding new wheels data
# 670416 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 674492 rows
# getting status...
# adding new link data
# adding new wheels data
# 677333 rows
# getting status...
# adding new link data
# adding new wheels data
# 680175 rows
# getting status...
# adding new link data
# adding new wheels data
# 683019 rows
# getting status...
# adding new link data
# adding new wheels data
# 685862 rows
# getting status...
# adding new link data
# adding new wheels data
# 688705 rows
# getting status...
# adding new link data
# adding new wheels data
# 691548 rows
# getting status...
# adding new link data
# adding new wheels data
# 694391 rows
# getting status...
# adding new link data
# adding new wheels data
# 697234 rows
# getting status...
# adding new link data
# adding new wheels data
# 700078 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 704150 rows
# getting status...
# adding new link data
# adding new wheels data
# 706995 rows
# getting status...
# adding new link data
# adding new wheels data
# 709841 rows
# getting status...
# adding new link data
# adding new wheels data
# 712691 rows
# getting status...
# adding new link data
# adding new wheels data
# 715540 rows
# getting status...
# adding new link data
# adding new wheels data
# 718389 rows
# getting status...
# adding new link data
# adding new wheels data
# 721239 rows
# getting status...
# adding new link data
# adding new wheels data
# 724089 rows
# getting status...
# adding new link data
# adding new wheels data
# 726937 rows
# getting status...
# adding new link data
# adding new wheels data
# 729783 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 733848 rows
# getting status...
# adding new link data
# adding new wheels data
# 736694 rows
# getting status...
# adding new link data
# adding new wheels data
# 739542 rows
# getting status...
# adding new link data
# adding new wheels data
# 742388 rows
# getting status...
# adding new link data
# adding new wheels data
# 745233 rows
# getting status...
# adding new link data
# adding new wheels data
# 748076 rows
# getting status...
# adding new link data
# adding new wheels data
# 750920 rows
# getting status...
# adding new link data
# adding new wheels data
# 753764 rows
# getting status...
# adding new link data
# adding new wheels data
# 756606 rows
# getting status...
# adding new link data
# adding new wheels data
# 759449 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 763504 rows
# getting status...
# adding new link data
# adding new wheels data
# 766343 rows
# getting status...
# adding new link data
# adding new wheels data
# 769182 rows
# getting status...
# adding new link data
# adding new wheels data
# 772020 rows
# getting status...
# adding new link data
# adding new wheels data
# 774858 rows
# getting status...
# adding new link data
# adding new wheels data
# 777695 rows
# getting status...
# adding new link data
# adding new wheels data
# 780531 rows
# getting status...
# adding new link data
# adding new wheels data
# 783369 rows
# getting status...
# adding new link data
# adding new wheels data
# 786206 rows
# getting status...
# adding new link data
# adding new wheels data
# 789019 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 793045 rows
# getting status...
# adding new link data
# adding new wheels data
# 795856 rows
# getting status...
# adding new link data
# adding new wheels data
# 798666 rows
# getting status...
# adding new link data
# adding new wheels data
# 801485 rows
# getting status...
# adding new link data
# adding new wheels data
# 804302 rows
# getting status...
# adding new link data
# adding new wheels data
# 807124 rows
# getting status...
# adding new link data
# adding new wheels data
# 809950 rows
# getting status...
# adding new link data
# adding new wheels data
# 812777 rows
# getting status...
# adding new link data
# adding new wheels data
# 815604 rows
# getting status...
# adding new link data
# adding new wheels data
# 818431 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 822479 rows
# getting status...
# adding new link data
# adding new wheels data
# 825307 rows
# getting status...
# adding new link data
# adding new wheels data
# 828136 rows
# getting status...
# adding new link data
# adding new wheels data
# 830964 rows
# getting status...
# adding new link data
# adding new wheels data
# 833791 rows
# getting status...
# adding new link data
# adding new wheels data
# 836617 rows
# getting status...
# adding new link data
# adding new wheels data
# 839443 rows
# getting status...
# adding new link data
# adding new wheels data
# 842269 rows
# getting status...
# adding new link data
# adding new wheels data
# 845095 rows
# getting status...
# adding new link data
# adding new wheels data
# 847921 rows
# getting status...
# adding new lime data
# adding new link data
# adding new wheels data
# 851968 rows
# getting status...
# adding new link data
# adding new wheels data
# 854794 rows
# getting status...
# adding new link data
# adding new wheels data
# 857620 rows
# getting status...
# adding new link data
# adding new wheels data
# 860445 rows
# getting status...
# adding new link data
# adding new wheels data
# 863279 rows
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7c25b17477a0> in <module>
#      17         data = pd.concat([data, frames_new[2]], ignore_index=True)
#      18     print(f'{data.shape[0]} rows')
# ---> 19     time.sleep(30)
#
# KeyboardInterrupt:

# %%
print(data.head)
# Out:
# <bound method NDFrame.head of        company                               bike_id   timestamp      lat  \
# 0         lime  5c3da794-bf97-4eb3-841c-9afec2cfcc39  1626455133  47.5508
# 1         lime  cb8fec70-c878-4abf-862d-babfefe0f0b0  1626455133  47.5372
# 2         lime  fd0390bf-a29b-4232-ae48-e51b1a4463e1  1626455133  47.5701
# 3         lime  391f57bf-6e52-4f42-8bf3-fb10351e8e48  1626455133  47.6202
# 4         lime  9dfbc0d2-c30c-4f82-9170-35d432f10445  1626455133  47.5157
# ...        ...                                   ...         ...      ...
# 863274  wheels  13e4efc4-0e38-4808-a47a-edac5075f804  1626464492  47.6205
# 863275  wheels  09d8e84c-bb2e-47d3-baeb-3b1472c7abc6  1626464492  47.6309
# 863276  wheels  e5d429a5-fab9-40ad-8ca7-262285b312f4  1626464492  47.6323
# 863277  wheels  e79cccf6-66b2-40d5-a4ba-d57c9d151a90  1626464492  47.6907
# 863278  wheels  631115f3-584c-44b5-beee-a432ad682348  1626464492  47.6162
#
#               lon  is_reserved  is_disabled vehicle_type  vehicle_type_id
# 0       -122.2655            0            0         bike              NaN
# 1       -122.2702            0            0         bike              NaN
# 2       -122.2774            0            0         bike              NaN
# 3       -122.2807            0            0         bike              NaN
# 4       -122.2814            0            0         bike              NaN
# ...           ...          ...          ...          ...              ...
# 863274    -122.34            0            1          NaN              NaN
# 863275   -122.325            0            0          NaN              NaN
# 863276   -122.372            0            0          NaN              NaN
# 863277   -122.356            0            0          NaN              NaN
# 863278   -122.331            0            1          NaN              NaN
#
# [863279 rows x 9 columns]>

# %%
data.to_csv('data/scooterdata20210716.csv', index=False)

# %%
idnum = data['bike_id'][3020]
data[data['bike_id']==idnum]
# Out:
#        company                               bike_id   timestamp      lat  \
# 3020      link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626455134  47.6352
# 5830      link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626455135  47.6352
# 8632      link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626455167  47.6352
# 11430     link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626455198  47.6352
# 14232     link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626455230  47.6352
# ...        ...                                   ...         ...      ...
# 850950    link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626464360  47.6353
# 853776    link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626464393  47.6353
# 856602    link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626464426  47.6353
# 859427    link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626464459  47.6353
# 862256    link  4beff7c1-4289-4cd9-a2b1-094d64a39fe7  1626464492  47.6353
#
#             lon  is_reserved  is_disabled vehicle_type  vehicle_type_id
# 3020   -122.342            0            0          NaN              1.0
# 5830   -122.342            0            0          NaN              1.0
# 8632   -122.342            0            0          NaN              1.0
# 11430  -122.342            0            0          NaN              1.0
# 14232  -122.342            0            0          NaN              1.0
# ...         ...          ...          ...          ...              ...
# 850950 -122.342            0            0          NaN              1.0
# 853776 -122.342            0            0          NaN              1.0
# 856602 -122.342            0            0          NaN              1.0
# 859427 -122.342            0            0          NaN              1.0
# 862256 -122.342            0            0          NaN              1.0
#
# [291 rows x 9 columns]
