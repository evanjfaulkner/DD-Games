# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../Admissions_Data/Admission_Predict_V1.csv', )

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df[df['University Rating']==1].plot.scatter(x='GRE Score',y='Chance of Admit',xlim=(290,340),ylim=(0,1))
df[df['University Rating']==2].plot.scatter(x='GRE Score',y='Chance of Admit',xlim=(290,340),ylim=(0,1))
df[df['University Rating']==3].plot.scatter(x='GRE Score',y='Chance of Admit',xlim=(290,340),ylim=(0,1))
df[df['University Rating']==4].plot.scatter(x='GRE Score',y='Chance of Admit',xlim=(290,340),ylim=(0,1))
df[df['University Rating']==5].plot.scatter(x='GRE Score',y='Chance of Admit',xlim=(290,340),ylim=(0,1))
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='Chance of Admit'>

# %%
df.plot.scatter(x='University Rating',y='Chance of Admit')
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='Chance of Admit'>

# %%
df['University Rating'].hist(bins=5)
# Out:
# <AxesSubplot:>
